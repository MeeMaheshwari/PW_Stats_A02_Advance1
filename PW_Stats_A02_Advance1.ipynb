# %% [markdown]
# # Statistics Advance Part 1

# %% [markdown]
# #     Theory Section

# %% [markdown]
# **Q 1.  What is a random variable in probability theory?**

# %% [markdown]
# **Ans.**
# - In probability theory, a random variable is a function that assigns a numerical value to each outcome in a sample space of a random experiment.
# -  It represents the outcomes of a random phenomenon.
# - For example, if you roll a die, the number that comes up is a random variable, because it’s uncertain until the die is rolled.
#
# - Two Key Types:
# 1. Discrete Random Variable:
#     - Takes on a countable number of possible values.
#     - Example: The result of rolling a die (1, 2, 3, 4, 5, 6).
#
# 2. Continuous Random Variable:
#     - Takes on an infinite number of possible values within a given range.
#     - Example: The exact height of a person (e.g., 170.25 cm).

# %% [markdown]
# Example:
# - If you toss a fair coin:
#     - Let X be a random variable defined as:
#     - X = 1 if heads,
#     - X = 0 if tails.
#     - Then X is a discrete random variable.
#
# - Why It Matters:
#     - Random variables allow us to quantify uncertainty, enabling the use of tools like:
#          - Probability distributions
#          - Expected value
#          - Variance
#          - Standard deviation

# %% [markdown]
# **Q 2.  What are the types of random variables?**

# %% [markdown]
# **Ans:** There are two main types of random variables in probability theory:
#
# 1. Discrete Random Variable
#     - Takes countable values (finite or countably infinite).
#     - Examples: 0, 1, 2, 3, …
#     - Often used in scenarios involving counts.
#
#     - Examples:
#         - Number of heads in 5 coin tosses.
#         - Number of students present in a class.
#         - Rolling a die: values = {1, 2, 3, 4, 5, 6}.
#
# 2. Continuous Random Variable
#     - Takes uncountably infinite values within an interval.
#     - Can take any value within a range.
#     - Often used in scenarios involving measurements.
#
#     - Examples:
#         - Height or weight of a person.
#         - Time taken to complete a task.
#         - Temperature on a given day.

# %% [markdown]
# **Q 3. What is the difference between discrete and continuous distributions?**

# %% [markdown]
# **Ans.** The difference between discrete and continuous distributions lies in the type of values the random variable can take and how probabilities are assigned:

# %% [markdown]
# 1. Discrete Distribution:
#     - Deals with discrete random variables (countable outcomes).
#     - Probabilities are assigned to specific values.
#     - Represented by a probability mass function (PMF).
#     - Example:
#         - Tossing a coin 3 times → Number of heads: 0, 1, 2, or 3
#         - Each outcome has a specific probability.
# 2. Continuous Distribution
#     - Deals with continuous random variables (uncountably infinite values).
#     - Probabilities are assigned over intervals, not individual values.
#     - Represented by a probability density function (PDF).
#     - Example:
#         - Height of people: Values like 170.25 cm, 170.251 cm, etc.
#         - Probability of exactly 170 cm = 0; but probability between 169.5 and 170.5 is positive.

# %% [markdown]
# **Q 4. What are probability distribution functions (PDF)?**

# %% [markdown]
# **Ans.** In probability theory, a probability distribution function (PDF) describes how the values of a random variable are distributed—that is, how likely different outcomes are.

# %% [markdown]
# There are two main types, depending on whether the random variable is discrete or continuous:

# %% [markdown]
# ### 1. For Discrete Random Variables:
#
# **Probability Mass Function (PMF)**
# - Gives the probability that a **discrete random variable** is exactly equal to some value.
# - Notation:
#
# $$
# P(X = x)
# $$
#
# - Example: Tossing a fair die
# $$
# P(X = 3) = \frac{1}{6}
# $$
# ---
#
# ### 2. For Continuous Random Variables:
#
# **Probability Density Function (PDF)**
# - Describes the *relative likelihood* for a **continuous random variable** to take on a value.
# - Probability is found **over an interval**, not at a single point.
# - The area under the curve between two values represents the probability:
#
# $$
# P(a \leq X \leq b) = \int_a^b f(x)\, dx
# $$
#
# - For any single value:
# $$
# P(X = x) = 0
# $$
# (because there's an infinite number of possible values)

# %% [markdown]
# Example: Normal distribution with mean = 0 and standard deviation = 1
# - Bell-shaped curve
# - PDF gives higher values near the mean

# %% [markdown]
# **Q 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?**

# %% [markdown]
# **Ans.**

# %% [markdown]
# | Feature            | [Probability Distribution Function (PDF)](w)                                                                                             | [Cumulative Distribution Function (CDF)](w)                                                        |
# | ------------------ | ---------------------------------------------------------------------------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------- |
# | **Definition**     | Describes the **likelihood** of a random variable taking a specific value (for discrete) or falling within an interval (for continuous). | Describes the **probability** that a random variable is **less than or equal to** a certain value. |
# | **Representation** | $f(x)$                                                                                                                                   | $F(x) = P(X \leq x)$                                                                               |
# | **Values**         | For continuous: $f(x) \geq 0$, but not a probability directly. <br> For discrete: $P(X = x)$.                                            | Always between 0 and 1.                                                                            |
# | **Use**            | Tells how **densely** the values are distributed.                                                                                        | Tells the **accumulated probability** up to a point.                                               |
# | **Graph**          | Usually a curve that peaks and falls (like bell-shaped for normal distribution).                                                         | Always a **non-decreasing** curve from 0 to 1.                                                     |
# | **Relation**       | CDF is the **integral** (area under curve) of the PDF for continuous variables:  <br> $F(x) = \int_{-\infty}^{x} f(t)\,dt$               | PDF is the **derivative** of the CDF (if it exists):  <br> $f(x) = \frac{d}{dx}F(x)$               |

# %% [markdown]
# **Q 6.  What is a discrete uniform distribution?**

# %% [markdown]
# **Ans.**

# %% [markdown]
# A **discrete uniform distribution** is a probability distribution in which all outcomes are **equally likely**.
#
# If a random variable \( X \) can take on \( n \) distinct values \( x_1, x_2, ..., x_n \), then:
#
# $$
# P(X = x_i) = \frac{1}{n}, \quad \text{for } i = 1, 2, ..., n
# $$
#
# ---
#
# ###  Example:
# - Rolling a fair 6-sided die:
#   - Possible outcomes: \( \{1, 2, 3, 4, 5, 6\} \)
#   - Probability of each outcome:
#
# $$
# P(X = x) = \frac{1}{6}
# $$
#
# ---
#
# ###  Properties:
# - **Mean** (Expected Value):
#
# $$
# \mu = \frac{a + b}{2}
# $$
#
# - **Variance**:
#
# $$
# \sigma^2 = \frac{(b - a + 1)^2 - 1}{12}
# $$
#
# Where \( a \) and \( b \) are the smallest and largest values that \( X \) can take.
#
# ---
#
# ###  Use Cases:
# - Fair dice rolls
# - Random draws where each value is equally likely

# %% [markdown]
# **Q 7. What are the key properties of a Bernoulli distribution?**

# %% [markdown]
# **Ans.**

# %% [markdown]
# The **Bernoulli distribution** models a random experiment with only **two possible outcomes**: 1 (success) or 0 (failure).
#
# ---
#
# ##  Key Properties:
#
# ### 1. Binary Outcomes:
# - The random variable \( X \in \{0, 1\} \)
# - Typically:
#   - \( X = 1 \rightarrow \text{success} \)
#   - \( X = 0 \rightarrow \text{failure} \)
#
# ---
# ![image.png](attachment:0cc8fd1b-eef9-4be4-a29a-c5bb523fb1e7.png)
#
# ---
#
# ### 8. Memoryless Property:
#
# - The Bernoulli distribution **does not** have the memoryless property.
#
# ---
#
# ### 9. Relation to Other Distributions:
#
# - A **Binomial distribution** with \( n = 1 \) is a Bernoulli distribution.
# - It is a special case of the **Categorical distribution** with 2 classes.

# %% [markdown]
# **Q 8. What is the binomial distribution, and how is it used in probability?**

# %% [markdown]
# **Ans.** The **Binomial Distribution** is a discrete probability distribution that models the number of successes in a fixed number of independent **Bernoulli trials**, each with the same probability of success.
#
# ---
#
# ###  Key Characteristics:
# - The experiment consists of **n independent trials**.
# - Each trial has **only two outcomes**: Success (S) or Failure (F).
# - The **probability of success (p)** remains constant for each trial.
# - The **random variable X** represents the number of successes in n trials.
#
# ---
#
# ###  Probability Mass Function (PMF):
#
# The probability of observing exactly \( k \) successes in \( n \) trials is given by:
#
# \[
# P(X = k) = \binom{n}{k} p^k (1 - p)^{n - k}
# \]
#
# Where:
# - \( \binom{n}{k} = \frac{n!}{k!(n-k)!} \) is the **binomial coefficient**,
# - \( p \) is the probability of success,
# - \( (1 - p) \) is the probability of failure,
# - \( k = 0, 1, 2, ..., n \)
#
# ---
#
# ###  Usage in Probability:
#
# Binomial distribution is used when:
# - You want to find the probability of a **specific number of successes** (like getting 3 heads in 5 coin tosses).
# - Modeling **binary outcomes** like pass/fail, yes/no, success/failure in repeated experiments.
#
# ---
#
# ###  Example:
#
# If you flip a fair coin 10 times, what is the probability of getting exactly 6 heads?
#
# Let \( n = 10 \), \( k = 6 \), and \( p = 0.5 \):
#
# \[
# P(X = 6) = \binom{10}{6} (0.5)^6 (0.5)^4 = \binom{10}{6} (0.5)^{10}
# \]

# %% [markdown]
# **Q 9. What is the Poisson distribution and where is it applied?**

# %% [markdown]
# **Ans.** The **Poisson Distribution** is a discrete probability distribution that expresses the probability of a given number of events occurring in a **fixed interval of time or space**, assuming the events occur with a known constant mean rate and independently of the time since the last event.
#
# ---
#
# ###  Key Characteristics:
# - It models the **number of occurrences** of an event in a fixed interval (time, area, volume, etc.).
# - Events occur **independently**.
# - The **average rate (λ or lambda)** of events is constant.
# - Two events **cannot occur at the exact same instant**.
#
# ---
#
# ###  Probability Mass Function (PMF):
#
# The probability of observing exactly \( k \) events is given by:
#
# \[
# P(X = k) = \frac{e^{-\lambda} \lambda^k}{k!}
# \]
#
# Where:
# - \( \lambda \) = expected number of occurrences in the interval (mean rate),
# - \( k \) = actual number of occurrences (0, 1, 2, ...),
# - \( e \) = Euler’s number (approximately 2.71828).
#
# ---
#
# ###  Applications of Poisson Distribution:
#
# Poisson distribution is used when modeling:
# - The number of **emails received per hour**.
# - The number of **accidents at a traffic signal** per week.
# - The number of **calls at a call center** in a given time frame.
# - The number of **decay events** per second from a radioactive source.
# - The number of **spelling errors per page** in typed text.
#
# ---
#
# ###  Example:
#
# If a call center receives an average of 5 calls per hour, what is the probability it receives exactly 3 calls in an hour?
#
# Let \( \lambda = 5 \), \( k = 3 \):
#
# \[
# P(X = 3) = \frac{e^{-5} \cdot 5^3}{3!} = \frac{e^{-5} \cdot 125}{6}
# \]

# %% [markdown]
# **Q 10.  What is a continuous uniform distribution?**

# %% [markdown]
# **Ans.** The **Continuous Uniform Distribution** is a type of probability distribution in which **all outcomes in a continuous interval are equally likely**. It is defined over an interval \([a, b]\), where:
# - Every value between \(a\) and \(b\) is **equally probable**.
# - The distribution has a **constant probability density**.
#
# ---
#
# ###  Key Properties:
# - **Support**: \( a \leq x \leq b \)
# - **Probability Density Function (PDF)**:
#
# \[
# f(x) =
# \begin{cases}
# \frac{1}{b - a}, & \text{for } a \leq x \leq b \\
# 0, & \text{otherwise}
# \end{cases}
# \]
#
# - **Mean** (Expected value):
#
# \[
# \mu = \frac{a + b}{2}
# \]
#
# - **Variance**:
#
# \[
# \sigma^2 = \frac{(b - a)^2}{12}
# \]
#
# ---
#
# ###  Applications:
#
# Continuous uniform distribution is used when:
# - The probability of any value in a given range is **equally likely**.
# - **Random number generation** within a fixed range.
# - **Modeling measurement errors** with no known bias.
# - **Simulations**, where equally likely outcomes are needed over a continuous range.
#
# ---
#
# ###  Example:
#
# If a bus arrives at a stop **every 30 minutes**, and you arrive at a **random time**, the waiting time is uniformly distributed between 0 and 30 minutes.
#
# Let \( a = 0 \), \( b = 30 \):
#
# \[
# f(x) = \frac{1}{30}, \quad \text{for } 0 \leq x \leq 30
# \]

# %% [markdown]
# **Q 11.  What are the characteristics of a normal distribution?**

# %% [markdown]
# **Ans.** The **Normal Distribution** (or Gaussian distribution) is a **bell-shaped**, **symmetric** probability distribution defined by its **mean (μ)** and **standard deviation (σ)**.
#
# ---
#
# ###  Key Characteristics:
# - **Symmetric** about the mean \( \mu \)
# - **Mean = Median = Mode**
# - Follows the **68-95-99.7 Rule**:
#   - ~68% of data within \( \mu \pm 1\sigma \)
#   - ~95% within \( \mu \pm 2\sigma \)
#   - ~99.7% within \( \mu \pm 3\sigma \)
# - Total area under the curve = **1**
# - Tails extend infinitely in both directions
#
# ---
#
# ###  Probability Density Function (PDF):
#
# \[ f(x) = \frac{1}{\sigma \sqrt{2\pi}} e^{-\frac{(x - \mu)^2}{2\sigma^2}}\]
#
# ---
#
# ###  Applications:
# Used in **natural and social sciences**, **statistics**, **machine learning**, and **quality control**.

# %% [markdown]
# **Q 12.  What is the standard normal distribution, and why is it important?**

# %% [markdown]
# **Ans.** The **Standard Normal Distribution** is a special case of the **normal distribution** with:
#
# - **Mean (μ) = 0**
# - **Standard deviation (σ) = 1**
#
# It is denoted as:
#
# \[
# Z \sim \mathcal{N}(0, 1)
# \]
#
# ---
#
# ###  Importance:
# - Simplifies probability calculations using **Z-scores**
# - Allows comparison across different normal distributions
# - Used in **hypothesis testing**, **confidence intervals**, and **standardization**
#
# ---
#
# ###  Z-Score Formula:
#
# \[
# Z = \frac{X - \mu}{\sigma}
# \]
#
# Where:
# - \( X \) is the raw score,
# - \( \mu \) is the mean,
# - \( \sigma \) is the standard deviation
#
# ---
#
# ###  Applications:
# - **Standardizing** variables
# - **Finding probabilities** from Z-tables
# - Common in **statistics** and **data analysis**

# %% [markdown]
# **Q 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?**

# %% [markdown]
# **Ans.** ###  Central Limit Theorem (CLT)
#
# The **Central Limit Theorem** states that the **sampling distribution** of the sample mean approaches a **normal distribution** as the **sample size (n)** becomes large, **regardless of the population’s distribution**, provided the data are independent and identically distributed.
#
# ---
#
# ###  Key Points:
# - Applies when \( n \geq 30 \) (rule of thumb)
# - Population can be any shape (not necessarily normal)
# - The sampling distribution of the mean will have:
#   - Mean \( \mu \)
#   - Sandard deviation \( \frac{\sigma}{\sqrt{n}} \) (called **Standard Error**)
#
# ---
#
# ### Why It's Important:
# - **Enables use of normal distribution** for inference
# - Foundation for **confidence intervals** and **hypothesis testing**
# - Allows reliable conclusions from **sample data**
#
# ---
#
# ###  Formula:
#
# If \( \bar{X} \) is the sample mean:
#
# \[
# \bar{X} \sim \mathcal{N} \left( \mu, \frac{\sigma}{\sqrt{n}} \right)
# \]

# %% [markdown]
# **Q 14. How does the Central Limit Theorem relate to the normal distribution?**

# %% [markdown]
# **Ans.** The **Central Limit Theorem (CLT)** explains the connection between any population distribution and the **normal distribution** through **sampling**.
#
# ---
#
# ###  Relationship:
# - No matter the shape of the original population distribution,
# - The **distribution of the sample means** will approach a **normal distribution** as the **sample size (n)** increases.
# - This makes the **normal distribution a universal tool** in statistics.
#
# ---
#
# ###  Summary:
#
# If \( X \) is any random variable with mean \( \mu \) and standard deviation \( \sigma \), then the **sampling distribution of the sample mean** \( \bar{X} \) tends toward:
#
# \[
# \bar{X} \sim \mathcal{N} \left( \mu, \frac{\sigma}{\sqrt{n}} \right) \quad \text{as } n \to \infty
# \]
#
# ---
#
# ###  Why It Matters:
# - Justifies the use of **normal-based methods** (e.g., Z-tests, t-tests)
# - Enables **probability estimates** and **inference** from samples, even when data are not normally distributed

# %% [markdown]
# **Q 15. What is the application of Z statistics in hypothesis testing?**

# %% [markdown]
# **Ans.** **Application of Z-Statistics in Hypothesis Testing**
#
# **Z-statistics** are used in hypothesis testing when the population **standard deviation is known** and the sample size is large (\( n \geq 30 \)).
#
# ---
#
# ###  Steps in Z-Test:
#
# 1. **State Hypotheses**:
#    - Null hypothesis \( H_0 \): no effect or difference
#    - Alternative hypothesis \( H_1 \): effect or difference exists
#
# 2. **Compute Z-Statistic**:
#
# \[
# Z = \frac{\bar{X} - \mu_0}{\sigma / \sqrt{n}}
# \]
#
# Where:
# - \( \bar{X} \) = sample mean
# - \( \mu_0 \) = population mean under \( H_0 \)
# - \( \sigma \) = population standard deviation
# - \( n \) = sample size
#
# 3. **Compare Z with critical value** (from Z-table) or calculate **p-value**.
#
# 4. **Decision**:
#    - If \( |Z| > Z_{\text{critical}} \), **reject \( H_0 \)**
#    - Or if \( p < \alpha \), **reject \( H_0 \)**
#
# ---
#
# ###  Common Applications:
# - Testing whether a sample mean differs from a known population mean
# - Quality control and manufacturing
# - Clinical trials and experiments
#
# ---
#
# ###  Example:
# Testing if a sample of test scores differs significantly from the national average.

# %% [markdown]
# **Q 16. How do you calculate a Z-score, and what does it represent?**

# %% [markdown]
# **Ans.** **Z-Score: Definition and Calculation**
#
# A **Z-score** measures how many **standard deviations** a data point is from the **mean**.
#
# ---
#
# ### 📐 Z-Score Formula:
#
# \[
# Z = \frac{X - \mu}{\sigma}
# \]
#
# Where:
# - \( X \) = raw score
# - \( \mu \) = population mean
# - \( \sigma \) = population standard deviation
#
# ---
#
# ###  What It Represents:
# - \( Z = 0 \): value is **exactly at the mean**
# - \( Z > 0 \): value is **above the mean**
# - \( Z < 0 \): value is **below the mean**
#
# Z-scores are used to:
# - **Standardize** data
# - Compare values from **different distributions**
# - Find **percentiles** using the **standard normal distribution**
#
# ---
#
# ###  Example:
# If a student scores 85 on a test with mean = 70 and std. dev. = 10:
#
# \[
# Z = \frac{85 - 70}{10} = 1.5
# \]
#
#  The score is **1.5 standard deviations above the mean**

# %% [markdown]
# **Q 17. What are point estimates and interval estimates in statistics?**

# %% [markdown]
# **Ans.**

# %% [markdown]
# ### Point Estimates vs. Interval Estimates
#
# In statistics, both **point estimates** and **interval estimates** are used to infer population parameters from sample data.
#
# ---
#
# ###  Point Estimate:
# A **single value** used to estimate a population parameter.
#
# - Example: Sample mean \( \bar{X} \) is a point estimate of the population mean \( \mu \).
#
# ---
#
# ###  Interval Estimate:
# A **range of values** (with a confidence level) likely to contain the population parameter.
#
# - Example: A 95% **confidence interval** for the population mean \( \mu \) is:
#
# \[
# \bar{X} \pm Z_{\alpha/2} \cdot \frac{\sigma}{\sqrt{n}}
# \]
#
# ---
#
# ###  Summary:
# | Type             | Definition                          | Example                       |
# |------------------|--------------------------------------|-------------------------------|
# | Point Estimate   | Single best guess of a parameter     | \( \bar{X} = 50 \)            |
# | Interval Estimate| Range with confidence level          | \( 50 \pm 1.96 \cdot SE \)    |
#
# ---
#
# ###  Use in Statistics:
# - **Point estimate** gives precision.
# - **Interval estimate** gives accuracy + uncertainty.

# %% [markdown]
# **Q 18. What is the significance of confidence intervals in statistical analysis?**

# %% [markdown]
# **Ans.**

# %% [markdown]
# ##  Confidence Intervals in Statistical Analysis
#
# **Confidence intervals (CIs)** are crucial in [statistical analysis](w) because they provide a **range of plausible values** for an unknown population parameter, offering more insight than a single estimate.
#
# ---
#
# ### 🔹 Significance of Confidence Intervals
#
# 1. **Quantifies Uncertainty**
#    Confidence intervals express the **uncertainty** around a sample estimate. Instead of a single value, we get a range likely to contain the true population value.
#
# 2. **Provides a Margin of Error**
#    CIs include a **margin of error**, helping us assess the **precision** of our estimate.
#
# 3. **Informs Decision-Making**
#    Widely used in **hypothesis testing**, CIs help in making informed decisions in fields like medicine, economics, etc.
#
# 4. **More Informative Than Point Estimates**
#    A point estimate alone doesn’t show reliability. A CI adds context by including the confidence level (e.g., 95%).
#
# 5. **Basis for Comparing Groups**
#    If two CIs **do not overlap**, it often indicates a **statistically significant difference** between groups.
#
# ---
#
# ### 🔹 Example:
#
# > Suppose the average height from a sample is **170 cm** with a **95% CI of (168 cm, 172 cm)**.
# > This means we are **95% confident** that the **true population mean** lies between **168 cm and 172 cm**.
#
# ---
#
# ###  In Summary
#
# Confidence intervals help:
# - Measure **reliability** of estimates
# - Make **data-driven decisions**
# - Understand **statistical significance**

# %% [markdown]
# **Q 19.  What is the relationship between a Z-score and a confidence interval?**

# %% [markdown]
# **Ans.**

# %% [markdown]
# ##  Relationship Between Z-score and Confidence Interval
#
# The **Z-score** is essential in constructing a **confidence interval (CI)** when the population standard deviation is known.
#
# ---
#
# ### 🔹 How They Are Related
#
# - The Z-score tells us **how many standard deviations** a point is from the mean.
# - It is used to calculate the confidence interval as:
#
# \[
# \text{Confidence Interval} = \bar{x} \pm Z \cdot \left( \frac{\sigma}{\sqrt{n}} \right)
# \]
#
# Where:
# - \(\bar{x}\) = sample mean
# - \(\sigma\) = population standard deviation
# - \(n\) = sample size
# - \(Z\) = Z-score corresponding to the confidence level
#
# ---
#
# ### 🔹 Z-scores for Common Confidence Levels
#
# | Confidence Level | Z-score |
# |------------------|---------|
# | 90%              | 1.645   |
# | 95%              | 1.96    |
# | 99%              | 2.576   |
#
# ---
#
# ### 🔹 Key Insight
#
# - A **higher confidence level** requires a **larger Z-score**.
# - This results in a **wider confidence interval**.
#
# >  **Z-score connects the confidence level with how far we go from the mean to capture the true parameter.**

# %% [markdown]
# **Q 20. How are Z-scores used to compare different distributions?**

# %% [markdown]
# **Ans.**

# %% [markdown]
# ##  Comparing Different Distributions Using Z-scores
#
# **Z-scores** allow us to compare values from different distributions by converting them to a standard scale.
#
# ---
#
# ### 🔹 Z-score Formula
#
# \[
# Z = \frac{X - \mu}{\sigma}
# \]
#
# - \(X\) = raw score
# - \(\mu\) = mean of the distribution
# - \(\sigma\) = standard deviation
#
# ---
#
# ### 🔹 Why Use Z-scores?
#
# 1. **Standardization**
#    Converts values from different units or distributions to a common scale.
#
# 2. **Relative Comparison**
#    Shows how a value compares to its group or population.
#
# 3. **Cross-domain Comparisons**
#    Useful in comparing performance, measurements, etc., across different contexts.
#
# ---
#
# ### 🔹 Example Table
#
# | Distribution | Raw Score (X) | Mean (μ) | SD (σ) | Z-score |
# |--------------|----------------|-----------|--------|---------|
# | Math Exam    | 85             | 70        | 10     | 1.5     |
# | Physics Exam | 80             | 75        | 5      | 1.0     |
#
# >  Even though 80 is a high score, 85 in Math is more impressive **relative to the group** because it has a **higher Z-score**.
#
# ---
#
# ### 🔸 Conclusion:
#
# Z-scores allow for **fair comparisons** across different scales and distributions by measuring relative position in standard units.

# %% [markdown]
# **Q 21. What are the assumptions for applying the Central Limit Theorem?**

# %% [markdown]
# **Ans.**

# %% [markdown]
# ##  Assumptions for Applying the Central Limit Theorem (CLT)
#
# The **Central Limit Theorem** states that the sampling distribution of the sample mean becomes approximately **normal** as the **sample size increases**, given the following assumptions:
#
# ---
#
# ### 🔹 Key Assumptions:
#
# 1. **Independence of Observations**
#    Observations must be independent — one should not influence another.
#
# 2. **Random Sampling**
#    Samples should be randomly selected to represent the population well.
#
# 3. **Large Sample Size (n ≥ 30)**
#    Larger samples make the sampling distribution more normal.
#    - For skewed populations, even larger \(n\) is required.
#
# 4. **Finite Variance**
#    The population must have a **finite mean and variance**.
#
# 5. **Identically Distributed Observations**
#    All samples should come from the **same distribution**.
#
# ---
#
# ### 🔸 Note:
#
# - For **normally distributed populations**, CLT holds even for **small samples**.
# - For **non-normal** populations, the approximation improves as sample size **increases**.
#
# >  These assumptions ensure the sample mean follows a normal distribution, making **inference and hypothesis testing** valid.

# %% [markdown]
# **Q 22. What is the concept of expected value in a probability distribution?**

# %% [markdown]
# **Ans.**

# %% [markdown]
# ##  Expected Value in a Probability Distribution
#
# The **expected value (E[X])** of a random variable is the **long-run average** outcome of an experiment.
#
# ---
#
# ### 🔹 Discrete Random Variable
#
# For a discrete variable with values \(x_1, x_2, ..., x_n\) and probabilities \(P(x_1), P(x_2), ..., P(x_n)\):
#
# \[
# E(X) = \sum_{i=1}^{n} x_i \cdot P(x_i)
# \]
#
# ---
#
# ### 🔹 Continuous Random Variable
#
# If the variable has a **probability density function** \(f(x)\):
#
# \[
# E(X) = \int_{-\infty}^{\infty} x \cdot f(x) \, dx
# \]
#
# ---
#
# ### 🔹 Example: Fair 6-sided Die
#
# \[
# E(X) = \sum_{i=1}^{6} i \cdot \frac{1}{6} = \frac{21}{6} = 3.5
# \]
#
# Although you can't roll a 3.5, it's the average of many rolls.
#
# ---
#
# ###  Summary
#
# - Expected value = **weighted average** of outcomes
# - Reflects the **center** of the distribution
# - Helps in **decision making** and **risk assessment**

# %% [markdown]
# **Q 23. How does a probability distribution relate to the expected outcome of a random variable?**

# %% [markdown]
# **Ans.**

# %% [markdown]
# A **probability distribution** describes how the values of a **random variable** are distributed — that is, how **likely** each possible outcome is.
#
# The **expected outcome** (or **expected value**) of a random variable is essentially the **long-run average** value you would get **if the experiment were repeated many times**.
#
# ---
#
# ###  Relationship Explained:
#
# - The **probability distribution** assigns probabilities to all possible values of the random variable.
# - The **expected value** is a **weighted average** of those values, using the **probabilities as weights**.
#
# ---
#
# ### Mathematically:
#
# For a **discrete** random variable \( X \):
#
# \[
# \ mathbb{E}[X] = \sum x_i \cdot P(X = x_i)
# \]
#
# For a **continuous** random variable:
#
# \[
# \mathbb{E}[X] = \int_{-\infty}^{\infty} x \cdot f(x) \, dx
# \]
#
# Where \( f(x) \) is the probability density function (PDF).
#
# ---
#
# ###  Example:
#
# If you roll a fair 6-sided die:
#
# - Probability distribution: each value 1 to 6 has probability \( \frac{1}{6} \)
# - Expected value:
#   \[
#   E[X] = \frac{1 + 2 + 3 + 4 + 5 + 6}{6} = 3.5
#   \]
#
# ---
#
# ### In Summary:
#
# > A **probability distribution** provides the foundation for calculating the **expected value**, which summarizes the **average outcome** you'd expect over many trials of a random process.

# %% [markdown]
# #     Practical Section

# %% [markdown]
# **Q 1.  Write a Python program to generate a random variable and display its value?**

# %% [markdown]
# **Ans.**

# %%
import random

x = random.randint(1, 10)
print("Random Variable (Discrete):", x)

y = random.uniform(0, 1)
print("Random Variable (Continuous):", y)

z = random.gauss(100, 15)
print("Random Variable (Normal Distribution):", z)
# Out:
# Random Variable (Discrete): 1
# Random Variable (Continuous): 0.17677272201993688
# Random Variable (Normal Distribution): 74.22781177202893

# %% [markdown]
# **Q 2.  Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)?**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define parameters for the discrete uniform distribution
low = 1   # inclusive lower bound
high = 7  # exclusive upper bound (for values 1 to 6)

# Create discrete uniform distribution
dist = randint(low, high)

# Generate x values and corresponding PMF
x = np.arange(low, high)
pmf = dist.pmf(x)

# Plot PMF
plt.figure(figsize=(8, 5))
markerline, stemlines, baseline = plt.stem(x, pmf)
plt.setp(markerline, marker='o', markersize=8, color='blue')
plt.setp(stemlines, color='blue')
plt.setp(baseline, visible=False)

plt.title('PMF of Discrete Uniform Distribution (1 to 6)')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.grid(True)
plt.xticks(x)
plt.ylim(0, 0.3)
plt.show()

# %% [markdown]
# **Q 3.  Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.**

# %% [markdown]
# **Ans.**

# %%
def bernoulli_pdf(x, p):
    """
    Calculates the PDF of a Bernoulli distribution for a given x (0 or 1) and probability p.

    Parameters:
        x (int): Value of the random variable (0 or 1)
        p (float): Probability of success (0 <= p <= 1)

    Returns:
        float: Probability value (PDF)
    """
    if x not in [0, 1]:
        raise ValueError("x must be 0 or 1 in a Bernoulli distribution")
    if not 0 <= p <= 1:
        raise ValueError("p must be between 0 and 1")

    return p**x * (1 - p)**(1 - x)

# Example usage:
print("P(X=0) =", bernoulli_pdf(0, 0.6))
print("P(X=1) =", bernoulli_pdf(1, 0.6))
# Out:
# P(X=0) = 0.4
# P(X=1) = 0.6

# %% [markdown]
# **Q 4.  Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10       # number of trials
p = 0.5      # probability of success
size = 1000  # number of simulations

# Simulate binomial distribution
data = np.random.binomial(n, p, size)

# Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(data, bins=np.arange(-0.5, n+1.5, 1), density=True, edgecolor='black', align='mid')
plt.title(f'Binomial Distribution Histogram (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(range(n+1))
plt.grid(True)
plt.show()

# %% [markdown]
# **Q 5.  Create a Poisson distribution and visualize it using Python.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Define the rate parameter (λ)
lambda_ = 4

# Generate a range of x values
x = np.arange(0, 15)

# Compute the PMF of the Poisson distribution
pmf = poisson.pmf(x, mu=lambda_)

# Plot the PMF
plt.figure(figsize=(8, 5))
plt.stem(x, pmf, basefmt=" ")  # Removed use_line_collection
plt.title(f'Poisson Distribution (λ = {lambda_})')
plt.xlabel('Number of Events (x)')
plt.ylabel('Probability')
plt.grid(True)
plt.show()

# %% [markdown]
# **Q 6.  Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define range for discrete uniform distribution (1 to 6 inclusive)
low = 1
high = 7  # scipy's randint is upper-bound exclusive

# Create the distribution
dist = randint(low, high)

# Values to evaluate CDF
x = np.arange(low - 1, high + 1)  # includes one extra point below and above
cdf = dist.cdf(x)

# Plot the CDF
plt.figure(figsize=(8, 5))
plt.step(x, cdf, where='post', label='CDF', color='green')
plt.title('CDF of Discrete Uniform Distribution (1 to 6)')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.xticks(np.arange(low - 1, high + 1))
plt.yticks(np.linspace(0, 1, 6 + 2))
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **Q 7. Generate a continuous uniform distribution using NumPy and visualize it.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters of the uniform distribution
a = 0     # lower bound
b = 10    # upper bound
size = 10000  # number of samples

# Generate data from a uniform distribution
data = np.random.uniform(a, b, size)

# Plot the histogram (normalized to form a probability density)
plt.figure(figsize=(8, 5))
plt.hist(data, bins=50, density=True, alpha=0.7, color='skyblue', edgecolor='black')
plt.title(f'Continuous Uniform Distribution U({a}, {b})')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.grid(True)
plt.show()

# %% [markdown]
# **Q 8. Simulate data from a normal distribution and plot its histogram.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the normal distribution
mu = 0        # Mean
sigma = 1     # Standard deviation
size = 10000  # Number of samples

# Simulate data
data = np.random.normal(mu, sigma, size)

# Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(data, bins=50, density=True, alpha=0.7, color='lightcoral', edgecolor='black')
plt.title(f'Normal Distribution Histogram (μ = {mu}, σ = {sigma})')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.grid(True)
plt.show()

# %% [markdown]
# **Q 9.  Write a Python function to calculate Z-scores from a dataset and plot them.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    """
    Calculates Z-scores from a dataset and plots their histogram.

    Parameters:
        data (array-like): List or NumPy array of numerical values.
    """
    data = np.array(data)
    mean = np.mean(data)
    std = np.std(data)

    # Calculate Z-scores
    z_scores = (data - mean) / std

    # Plot histogram of Z-scores
    plt.figure(figsize=(8, 5))
    plt.hist(z_scores, bins=30, density=True, alpha=0.7, color='cornflowerblue', edgecolor='black')
    plt.title('Histogram of Z-scores')
    plt.xlabel('Z-score')
    plt.ylabel('Density')
    plt.grid(True)
    plt.axvline(0, color='black', linestyle='dashed', linewidth=1)  # Mean line
    plt.show()

    return z_scores

# Example usage:
sample_data = np.random.normal(loc=50, scale=10, size=1000)
z_scores = calculate_and_plot_z_scores(sample_data)

# %% [markdown]
# **Q 10.  Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt

def demonstrate_clt(dist_func, dist_params, sample_size=30, num_samples=1000):
    """
    Demonstrates the Central Limit Theorem using the specified distribution.

    Parameters:
        dist_func (function): The NumPy function to generate the non-normal distribution (e.g., np.random.exponential).
        dist_params (dict): Parameters for the distribution function.
        sample_size (int): Size of each random sample.
        num_samples (int): Number of samples to draw.
    """
    sample_means = []

    for _ in range(num_samples):
        sample = dist_func(size=sample_size, **dist_params)
        sample_means.append(np.mean(sample))

    # Plot histogram of sample means
    plt.figure(figsize=(8, 5))
    plt.hist(sample_means, bins=30, density=True, color='salmon', edgecolor='black', alpha=0.7)
    plt.title(f'CLT Demonstration (n={sample_size}, Samples={num_samples})\nNon-Normal Source: {dist_func.__name__}')
    plt.xlabel('Sample Mean')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.show()

# Example: Using exponential distribution (non-normal)
demonstrate_clt(np.random.exponential, {'scale': 2.0}, sample_size=30, num_samples=1000)

# %% [markdown]
# **Q 15. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def verify_clt_normal_distribution(mu=50, sigma=10, sample_size=30, num_samples=1000):
    """
    Simulate multiple samples from a normal distribution and verify CLT.

    Parameters:
        mu (float): Mean of the normal distribution
        sigma (float): Standard deviation of the normal distribution
        sample_size (int): Number of observations per sample
        num_samples (int): Number of samples to generate
    """
    sample_means = []

    for _ in range(num_samples):
        sample = np.random.normal(mu, sigma, sample_size)
        sample_means.append(np.mean(sample))

    # Convert to NumPy array
    sample_means = np.array(sample_means)

    # Plot histogram of sample means
    plt.figure(figsize=(8, 5))
    plt.hist(sample_means, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7)

    # Overlay theoretical normal curve for sample means
    x = np.linspace(mu - 4, mu + 4, 1000)
    pdf = norm.pdf(x, loc=mu, scale=sigma / np.sqrt(sample_size))
    plt.plot(x, pdf, 'r-', lw=2, label='Theoretical Normal (CLT)')

    # Labels and title
    plt.title(f'CLT Verification Using Normal Distribution\nn={sample_size}, Samples={num_samples}')
    plt.xlabel('Sample Mean')
    plt.ylabel('Density')
    plt.grid(True)
    plt.legend()
    plt.show()

# Example usage:
verify_clt_normal_distribution(mu=50, sigma=10, sample_size=30, num_samples=1000)

# %% [markdown]
# **Q 16. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    """
    Calculates and plots the Standard Normal Distribution (mean=0, std=1).
    """
    # Generate x values from -4 to +4
    x = np.linspace(-4, 4, 1000)

    # Compute the standard normal PDF values
    y = norm.pdf(x, loc=0, scale=1)

    # Plot the curve
    plt.figure(figsize=(8, 5))
    plt.plot(x, y, color='blue', lw=2, label='Standard Normal PDF')
    plt.title('Standard Normal Distribution (μ=0, σ=1)')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.axvline(0, color='black', linestyle='--', linewidth=1)
    plt.axvline(1, color='gray', linestyle='--', linewidth=1)
    plt.axvline(-1, color='gray', linestyle='--', linewidth=1)
    plt.show()

# Call the function
plot_standard_normal_distribution()

# %% [markdown]
# **Q 17. Generate random variables and calculate their corresponding probabilities using the binomial distribution.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

# Parameters for the binomial distribution
n = 10      # Number of trials
p = 0.5     # Probability of success
size = 1000 # Number of random samples

# Step 1: Generate random variables from binomial distribution
random_variables = np.random.binomial(n, p, size)

# Step 2: Calculate unique values and their corresponding PMF probabilities
x_vals = np.arange(0, n + 1)
pmf_vals = binom.pmf(x_vals, n, p)

# Optional: Display results
for x, prob in zip(x_vals, pmf_vals):
    print(f"P(X = {x}) = {prob:.4f}")

# Step 3: Plot the Binomial PMF
plt.figure(figsize=(8, 5))
plt.bar(x_vals, pmf_vals, color='skyblue', edgecolor='black')
plt.title(f'Binomial Distribution PMF (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(x_vals)
plt.grid(True)
plt.show()
# Out:
# P(X = 0) = 0.0010
# P(X = 1) = 0.0098
# P(X = 2) = 0.0439
# P(X = 3) = 0.1172
# P(X = 4) = 0.2051
# P(X = 5) = 0.2461
# P(X = 6) = 0.2051
# P(X = 7) = 0.1172
# P(X = 8) = 0.0439
# P(X = 9) = 0.0098
# P(X = 10) = 0.0010

# %% [markdown]
# **Q 18.  Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(x, mean, std):
    """
    Calculate the Z-score for a given data point.
    """
    return (x - mean) / std

def plot_standard_normal_with_z(z_score):
    """
    Plot standard normal distribution and highlight the Z-score.
    """
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x, 0, 1)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label='Standard Normal PDF', color='blue')
    plt.fill_between(x, 0, y, where=(x <= z_score), color='skyblue', alpha=0.5, label='Area ≤ Z')
    plt.axvline(z_score, color='red', linestyle='--', label=f'Z = {z_score:.2f}')
    plt.title('Z-score on Standard Normal Distribution')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.show()

# Example inputs
data_point = 75
mean = 70
std = 5

# Step 1: Calculate Z-score
z = calculate_z_score(data_point, mean, std)
print(f"Z-score for x = {data_point} is {z:.2f}")

# Step 2: Plot it on the standard normal distribution
plot_standard_normal_with_z(z)
# Out:
# Z-score for x = 75 is 1.00

# %% [markdown]
# **Q 19.  Implement hypothesis testing using Z-statistics for a sample datase.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
from scipy.stats import norm

def z_test(sample, population_mean, population_std, alpha=0.05):
    """
    Perform a one-sample Z-test.

    Parameters:
        sample (array-like): Sample data
        population_mean (float): Mean under the null hypothesis
        population_std (float): Known population standard deviation
        alpha (float): Significance level (default is 0.05 for a 95% confidence level)

    Returns:
        Z-score, p-value, and test result
    """
    sample = np.array(sample)
    sample_size = len(sample)
    sample_mean = np.mean(sample)

    # Calculate Z-score
    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    # Two-tailed p-value
    p_value = 2 * (1 - norm.cdf(abs(z_score)))

    # Decision
    reject_null = p_value < alpha
    result = "Reject H₀" if reject_null else "Fail to Reject H₀"

    # Output
    print(f"Sample Mean = {sample_mean:.2f}")
    print(f"Z-score = {z_score:.3f}")
    print(f"P-value = {p_value:.4f}")
    print(f"Decision at α = {alpha}: {result}")

    return z_score, p_value, result

#  Example usage
np.random.seed(0)
sample_data = np.random.normal(loc=52, scale=5, size=40)  # sample with mean ~52
population_mean = 50
population_std = 5
z_test(sample_data, population_mean, population_std, alpha=0.05)
# Out:
# Sample Mean = 53.56
# Z-score = 4.507
# P-value = 0.0000
# Decision at α = 0.05: Reject H₀
# (np.float64(4.506514289945271), np.float64(6.590124919769735e-06), 'Reject H₀')

# %% [markdown]
# **q 20.  Create a confidence interval for a dataset using Python and interpret the result.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
from scipy.stats import t

def confidence_interval(data, confidence=0.95):
    """
    Calculate and interpret the confidence interval for the mean of a dataset.

    Parameters:
        data (array-like): Sample data
        confidence (float): Confidence level (default is 0.95)

    Returns:
        Tuple containing (lower_bound, upper_bound)
    """
    data = np.array(data)
    n = len(data)
    mean = np.mean(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)  # sample standard error

    # t critical value
    t_crit = t.ppf((1 + confidence) / 2, df=n-1)

    # margin of error
    margin = t_crit * std_err

    # confidence interval
    lower = mean - margin
    upper = mean + margin

    # Print result
    print(f"Sample Mean = {mean:.2f}")
    print(f"{int(confidence*100)}% Confidence Interval: ({lower:.2f}, {upper:.2f})")
    print(f"Interpretation: We are {int(confidence*100)}% confident that the true population mean lies between {lower:.2f} and {upper:.2f}.")

    return lower, upper

#  Example usage
np.random.seed(42)
sample_data = np.random.normal(loc=100, scale=15, size=30)
confidence_interval(sample_data, confidence=0.95)
# Out:
# Sample Mean = 97.18
# 95% Confidence Interval: (92.14, 102.22)
# Interpretation: We are 95% confident that the true population mean lies between 92.14 and 102.22.
# (np.float64(92.13677771552751), np.float64(102.21881540894132))

# %% [markdown]
# **Q 21. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
from scipy.stats import t

def generate_normal_data(mu=100, sigma=15, size=30, seed=0):
    """
    Generate random data from a normal distribution.
    """
    np.random.seed(seed)
    return np.random.normal(loc=mu, scale=sigma, size=size)

def confidence_interval(data, confidence=0.95):
    """
    Calculate and interpret the confidence interval for the mean of the data.
    """
    n = len(data)
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)  # sample standard deviation
    std_error = sample_std / np.sqrt(n)

    # t-critical value for two-tailed interval
    t_crit = t.ppf((1 + confidence) / 2, df=n-1)

    # Margin of error
    margin = t_crit * std_error

    # Confidence interval
    lower = sample_mean - margin
    upper = sample_mean + margin

    # Output
    print(f"Sample Mean = {sample_mean:.2f}")
    print(f"{int(confidence*100)}% Confidence Interval = ({lower:.2f}, {upper:.2f})")
    print(f"Interpretation: We are {int(confidence*100)}% confident that the true population mean lies between {lower:.2f} and {upper:.2f}.")

    return lower, upper

#  Generate normal data
data = generate_normal_data(mu=100, sigma=15, size=30, seed=42)

#  Calculate and interpret confidence interval
confidence_interval(data, confidence=0.95)
# Out:
# Sample Mean = 97.18
# 95% Confidence Interval = (92.14, 102.22)
# Interpretation: We are 95% confident that the true population mean lies between 92.14 and 102.22.
# (np.float64(92.13677771552751), np.float64(102.21881540894132))

# %% [markdown]
# **Q 22.  Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_normal_pdf(mean=0, std_dev=1):
    """
    Calculates and plots the PDF of a normal distribution.

    Parameters:
        mean (float): Mean of the distribution
        std_dev (float): Standard deviation of the distribution
    """
    # Generate x values
    x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

    # Calculate the PDF using scipy
    pdf = norm.pdf(x, loc=mean, scale=std_dev)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf, label=f'N({mean}, {std_dev}²)', color='darkblue')
    plt.title('Normal Distribution - Probability Density Function (PDF)')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.axvline(mean, color='red', linestyle='--', label='Mean')
    plt.show()

#  Example usage
plot_normal_pdf(mean=100, std_dev=15)

# %% [markdown]
# **Q 23.  Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

def poisson_cdf_analysis(lam=3, max_x=10, x_value=4):
    """
    Calculates and interprets the CDF of a Poisson distribution.

    Parameters:
        lam (float): λ (rate parameter of the Poisson distribution)
        max_x (int): maximum value of x for plotting
        x_value (int): specific value to evaluate the CDF
    """
    # Calculate CDF at specific x
    cdf_value = poisson.cdf(x_value, mu=lam)
    print(f"P(X ≤ {x_value}) for Poisson(λ={lam}) = {cdf_value:.4f}")
    print(f"Interpretation: There is a {cdf_value*100:.2f}% chance that the number of events will be ≤ {x_value}.")

    # Values for plotting
    x = np.arange(0, max_x + 1)
    cdf_vals = poisson.cdf(x, mu=lam)

    # Plot the CDF
    plt.figure(figsize=(8, 5))
    plt.step(x, cdf_vals, where='post', color='green', label='CDF')
    plt.axvline(x_value, color='red', linestyle='--', label=f'x = {x_value}')
    plt.title(f'Cumulative Distribution Function (CDF) - Poisson(λ={lam})')
    plt.xlabel('x (Number of Events)')
    plt.ylabel('Cumulative Probability')
    plt.grid(True)
    plt.legend()
    plt.show()

#  Example usage
poisson_cdf_analysis(lam=3, max_x=10, x_value=4)
# Out:
# P(X ≤ 4) for Poisson(λ=3) = 0.8153
# Interpretation: There is a 81.53% chance that the number of events will be ≤ 4.

# %% [markdown]
# **Q 24.  Simulate a random variable using a continuous uniform distribution and calculate its expected value.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np

# Parameters for the uniform distribution
a = 10  # lower bound
b = 20  # upper bound
size = 10000  # number of random samples

# Simulate random variables
samples = np.random.uniform(a, b, size)

# Calculate sample mean (empirical expected value)
sample_mean = np.mean(samples)

# Calculate theoretical expected value
expected_value = (a + b) / 2

# Output
print(f"Theoretical Expected Value E[X] = {(a + b) / 2}")
print(f"Sample Mean from Simulation ≈ {sample_mean:.4f}")
print(f"Difference = {abs(sample_mean - expected_value):.4f}")
# Out:
# Theoretical Expected Value E[X] = 15.0
# Sample Mean from Simulation ≈ 14.9436
# Difference = 0.0564

# %% [markdown]
# **Q 25.  Write a Python program to compare the standard deviations of two datasets and visualize the difference.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt

def compare_std_devs(data1, data2, label1='Dataset 1', label2='Dataset 2'):
    # Calculate standard deviations
    std1 = np.std(data1, ddof=1)
    std2 = np.std(data2, ddof=1)

    # Print results
    print(f"{label1} - Standard Deviation: {std1:.4f}")
    print(f"{label2} - Standard Deviation: {std2:.4f}")
    print(f"Difference: {abs(std1 - std2):.4f}")

    # Plot histograms
    plt.figure(figsize=(10, 5))
    plt.hist(data1, bins=30, alpha=0.6, color='blue', label=label1, edgecolor='black')
    plt.axvline(np.mean(data1), color='blue', linestyle='dashed', linewidth=1)
    plt.axvline(np.mean(data1) + std1, color='blue', linestyle='solid', linewidth=1)
    plt.axvline(np.mean(data1) - std1, color='blue', linestyle='solid', linewidth=1)

    plt.hist(data2, bins=30, alpha=0.6, color='orange', label=label2, edgecolor='black')
    plt.axvline(np.mean(data2), color='orange', linestyle='dashed', linewidth=1)
    plt.axvline(np.mean(data2) + std2, color='orange', linestyle='solid', linewidth=1)
    plt.axvline(np.mean(data2) - std2, color='orange', linestyle='solid', linewidth=1)

    # Labels
    plt.title("Comparison of Standard Deviations")
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.legend()
    plt.grid(True)
    plt.show()

#  Example usage
np.random.seed(42)
data1 = np.random.normal(loc=50, scale=5, size=1000)
data2 = np.random.normal(loc=50, scale=10, size=1000)

compare_std_devs(data1, data2, label1='σ=5', label2='σ=10')
# Out:
# σ=5 - Standard Deviation: 4.8961
# σ=10 - Standard Deviation: 9.9745
# Difference: 5.0785

# %% [markdown]
# **Q 26. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np

# Step 1: Generate data from a normal distribution
np.random.seed(0)
data = np.random.normal(loc=100, scale=15, size=1000)

# Step 2: Calculate Range
data_range = np.max(data) - np.min(data)

# Step 3: Calculate IQR (Interquartile Range)
q1 = np.percentile(data, 25)  # 25th percentile
q3 = np.percentile(data, 75)  # 75th percentile
iqr = q3 - q1

# Output
print(f"Range: {data_range:.2f}")
print(f"Q1 (25th percentile): {q1:.2f}")
print(f"Q3 (75th percentile): {q3:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Range: 87.08
# Q1 (25th percentile): 89.52
# Q3 (75th percentile): 109.10
# Interquartile Range (IQR): 19.58

# %% [markdown]
# **Q 27.  Implement Z-score normalization on a dataset and visualize its transformation.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
import matplotlib.pyplot as plt

def z_score_normalization(data):
    """
    Applies Z-score normalization to the dataset.
    Returns the normalized data.
    """
    mean = np.mean(data)
    std = np.std(data)
    z_scores = (data - mean) / std
    return z_scores

def visualize_normalization(original, normalized):
    """
    Plots histograms before and after Z-score normalization.
    """
    plt.figure(figsize=(12, 5))

    # Original data
    plt.subplot(1, 2, 1)
    plt.hist(original, bins=30, color='skyblue', edgecolor='black')
    plt.title("Original Data")
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.grid(True)

    # Normalized data
    plt.subplot(1, 2, 2)
    plt.hist(normalized, bins=30, color='salmon', edgecolor='black')
    plt.title("Z-score Normalized Data")
    plt.xlabel("Z-score")
    plt.ylabel("Frequency")
    plt.grid(True)

    plt.tight_layout()
    plt.show()

#  Generate example dataset
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)

#  Apply Z-score normalization
z_scores = z_score_normalization(data)

#  Visualize the transformation
visualize_normalization(data, z_scores)

# %% [markdown]
# **Q 28. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.**

# %% [markdown]
# **Ans.**

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def analyze_normal_distribution_skew_kurtosis(mean=0, std=1, size=1000, seed=42):
    """
    Generates a normal distribution and calculates skewness and kurtosis.

    Parameters:
        mean (float): Mean of the normal distribution
        std (float): Standard deviation
        size (int): Number of samples
        seed (int): Random seed for reproducibility
    """
    # Generate normal data
    np.random.seed(seed)
    data = np.random.normal(loc=mean, scale=std, size=size)

    # Calculate skewness and kurtosis
    data_skewness = skew(data)
    data_kurtosis = kurtosis(data)  # Fisher's definition: normal = 0

    # Output results
    print(f"Skewness: {data_skewness:.4f}")
    print(f"Kurtosis (excess): {data_kurtosis:.4f}")

    # Interpretation
    if abs(data_skewness) < 0.5:
        print("Interpretation: The distribution is approximately symmetric.")
    elif data_skewness > 0:
        print("Interpretation: The distribution is positively skewed (right-tailed).")
    else:
        print("Interpretation: The distribution is negatively skewed (left-tailed).")

    if abs(data_kurtosis) < 0.5:
        print("Interpretation: The distribution is mesokurtic (similar to normal).")
    elif data_kurtosis > 0:
        print("Interpretation: The distribution is leptokurtic (heavier tails).")
    else:
        print("Interpretation: The distribution is platykurtic (lighter tails).")

#  Example usage
analyze_normal_distribution_skew_kurtosis(mean=100, std=15, size=1000)
# Out:
# Skewness: 0.1168
# Kurtosis (excess): 0.0662
# Interpretation: The distribution is approximately symmetric.
# Interpretation: The distribution is mesokurtic (similar to normal).
